# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.head(1)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
data.shape[0]
# Out:
# 636

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
data[['team1','team1','winner']]
# Out:
#                            team1                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1                 Mumbai Indians               Mumbai Indians
# 2                  Gujarat Lions                Gujarat Lions
# 3         Rising Pune Supergiant       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631             Delhi Daredevils             Delhi Daredevils
# 632                Gujarat Lions                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634                Gujarat Lions                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data.iloc[629]
# Out:
# id                            630
# season                       2016
# city                       Kanpur
# date                   2016-05-21
# team1              Mumbai Indians
# team2               Gujarat Lions
# toss_winner         Gujarat Lions
# toss_decision               field
# result                     normal
# dl_applied                      0
# winner              Gujarat Lions
# win_by_runs                     0
# win_by_wickets                  6
# player_of_match          SK Raina
# venue                  Green Park
# umpire1              AK Chaudhary
# umpire2                 CK Nandan
# umpire3                       NaN
# Name: 629, dtype: object

# %%
data.iloc[1:3]
# Out:
#    id  season    city        date           team1                   team2  \
# 1   2    2017    Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant
# 2   3    2017  Rajkot  2017-04-07   Gujarat Lions   Kolkata Knight Riders
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
#
#                                      venue         umpire1    umpire2  umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore     S Ravi      NaN
# 2   Saurashtra Cricket Association Stadium     Nitin Menon  CK Nandan      NaN

# %%
data.iloc[1:8:2]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 3           0         Kings XI Punjab            0               6
# ...

# %%
#fancy indexing
data.iloc[[1,3,5]]
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 3           0         Kings XI Punjab            0               6
# 5           0     Sunrisers Hyderabad            0               9
#
#   player_of_match                                      venue         umpire1  \
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
data.iloc[0,[1,2,10]]
# Out:
# season                   2017
# city                Hyderabad
# winner    Sunrisers Hyderabad
# Name: 0, dtype: object

# %%
mask=data['city']=='Pune'
data[mask].shape[0]
# Out:
# 32

# %%
data1=pd.read_csv('sonar data.csv')

# %%
data1
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.0200  207 non-null    float64
#  1   0.0371  207 non-null    float64
#  2   0.0428  207 non-null    float64
#  3   0.0207  207 non-null    float64
#  4   0.0954  207 non-null    float64
#  5   0.0986  207 non-null    float64
#  6   0.1539  207 non-null    float64
#  7   0.1601  207 non-null    float64
#  8   0.3109  207 non-null    float64
#  9   0.2111  207 non-null    float64
#  10  0.1609  207 non-null    float64
#  11  0.1582  207 non-null    float64
#  12  0.2238  207 non-null    float64
#  13  0.0645  207 non-null    float64
#  14  0.0660  207 non-null    float64
#  15  0.2273  207 non-null    float64
#  16  0.3100  207 non-null    float64
#  17  0.2999  207 non-null    float64
#  18  0.5078  207 non-null    float64
#  19  0.4797  207 non-null    float64
# ...

# %%
data1.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
mask=data1['R']=='M'
data1[mask].shape[0]
# Out:
# 111

# %%
mask=data1['R']=='M'
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 202     True
# 203     True
# 204     True
# 205     True
# 206     True
# Name: R, Length: 207, dtype: bool

# %%
data1[['0.0200','R']]
# Out:
#      0.0200  R
# 0    0.0453  R
# 1    0.0262  R
# 2    0.0100  R
# 3    0.0762  R
# 4    0.0286  R
# ..      ... ..
# 202  0.0187  M
# 203  0.0323  M
# 204  0.0522  M
# 205  0.0303  M
# 206  0.0260  M
#
# [207 rows x 2 columns]

# %%
new=data1['R']=="M"
data1[new]
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 96   0.0491  0.0279  0.0592  0.1270  0.1772  0.1908  0.2217  0.0768  0.1246
# 97   0.1313  0.2339  0.3059  0.4264  0.4010  0.1791  0.1853  0.0055  0.1929
# 98   0.0201  0.0423  0.0554  0.0783  0.0620  0.0871  0.1201  0.2707  0.1206
# 99   0.0629  0.1065  0.1526  0.1229  0.1437  0.1190  0.0884  0.0907  0.2107
# 100  0.0335  0.0134  0.0696  0.1180  0.0348  0.1180  0.1948  0.1607  0.3036
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
new=data1['R']=="M"
data1[new].shape[0]
# Out:
# 111

# %%
data1[new].shape
# Out:
# (111, 61)

# %%
new
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 202     True
# 203     True
# 204     True
# 205     True
# 206     True
# Name: R, Length: 207, dtype: bool

# %%
new.shape
# Out:
# (207,)

# %%
def count_of_value(value):
    sorted=data1['R']==value
    return data1[sorted]
    
count_of_value("M")
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 96   0.0491  0.0279  0.0592  0.1270  0.1772  0.1908  0.2217  0.0768  0.1246
# 97   0.1313  0.2339  0.3059  0.4264  0.4010  0.1791  0.1853  0.0055  0.1929
# 98   0.0201  0.0423  0.0554  0.0783  0.0620  0.0871  0.1201  0.2707  0.1206
# 99   0.0629  0.1065  0.1526  0.1229  0.1437  0.1190  0.0884  0.0907  0.2107
# 100  0.0335  0.0134  0.0696  0.1180  0.0348  0.1180  0.1948  0.1607  0.3036
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
count_of_value("")
# Out:
# 0

# %%
new_data=pd.read_csv('clothing.csv')

# %%
new_data
# Out:
#       tsales      sales  margin  nown   nfull   npart    naux  hoursw  \
# 0     750000   4411.765    41.0   1.0  1.0000  1.0000  1.5357      76
# 1    1926395   4280.878    39.0   2.0  2.0000  3.0000  1.5357     192
# 2    1250000   4166.667    40.0   1.0  2.0000  2.2222  1.4091     114
# 3     694227   2670.104    40.0   1.0  1.0000  1.2833  1.3673     100
# 4     750000  15000.000    44.0   2.0  1.9556  1.2833  1.3673     104
# ..       ...        ...     ...   ...     ...     ...     ...     ...
# 395   500000   5000.000    37.0   1.0  1.9231  1.0000  1.5357     104
# 396  5000000  16666.670    40.0   1.0  8.0000  9.0000  1.0000     120
# 397   517381   5173.810    40.0   1.0  1.0000  1.5946  1.5357      92
# 398  1252320   3339.520    36.0   1.0  2.0000  1.5946  2.0000     170
# 399   600000   8571.429    39.0   1.0  1.9556  1.2833  1.0000      74
#
#       hourspw       inv1       inv2  ssize  start
# 0    16.75596   17166.67   27177.04    170   41.0
# ...

# %%
new_data.shape
# Out:
# (400, 13)

# %%
screen=new_data['tsales']>1000000
new_data[screen]
# Out:
#       tsales      sales  margin    nown   nfull   npart    naux  hoursw  \
# 1    1926395   4280.878    39.0  2.0000  2.0000  3.0000  1.5357     192
# 2    1250000   4166.667    40.0  1.0000  2.0000  2.2222  1.4091     114
# 6    1300000   3250.000    39.0  1.2228  1.0000  3.0000  4.0000     161
# 8    1200000   2666.667    41.0  1.0000  3.0000  2.2222  1.4091     158
# 13   1500000  13636.360    37.0  1.0000  5.0000  1.0000  1.0000     305
# ..       ...        ...     ...     ...     ...     ...     ...     ...
# 390  1993529   1642.116    48.0  2.0000  5.0000  5.0000  3.0000     385
# 393  1800000   3964.758    48.0  3.0000  2.2656  3.0000  1.3333     221
# 394  1164688   5823.440    46.0  1.0000  1.0000  1.0000  1.3673     117
# 396  5000000  16666.670    40.0  1.0000  8.0000  9.0000  1.0000     120
# 398  1252320   3339.520    36.0  1.0000  2.0000  1.5946  2.0000     170
#
#       hourspw       inv1       inv2  ssize  start
# 1    22.49376   17166.67   27177.04    450   39.0
# ...
